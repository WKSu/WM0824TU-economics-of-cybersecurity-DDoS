# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# data source: https://surfdrive.surf.nl/files/index.php/s/CZWfWQp3VKGKa8m
df = pd.read_csv('data_with_ports.csv.gz', sep='|', compression='gzip')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (15,17,19,27) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# parse string to datetime format
df['date'] = pd.to_datetime(df['date'], format='%Y-%m-%d')
df['start_time'] = pd.to_datetime(df['start_time'], format='%Y-%m-%dT%H:%M:%S+09:00')
df['stop_time'] = pd.to_datetime(df['stop_time'], format='%Y-%m-%dT%H:%M:%S+09:00')

# %%
# remove reserved ips

reserved_ips = [
    "0.",       # software
    "10.",      # private network
    "100.",     # private network
    "169.254.", # subnet
    "172.",     # private network
    "192."      # private network
]

for ips in reserved_ips:
    df = df[~(df.org.isna() & df.target_ip.str.startswith(ips))]

# %%
from random import randint

df.iloc[randint(0, len(df))]
# Out:
# target_ip                                                   199.180.255.217
# date                                                    2014-08-19 00:00:00
# sensor_id                                                         sensor006
# service                                                                 ntp
# start_time                                              2014-08-19 15:00:05
# stop_time                                               2014-08-19 15:06:48
# duration                                                                403
# packets                                                                1124
# raw_country                                                   United States
# raw_as                                        AS46562 Colo at 55<comma> LLC
# raw_hostname                                                    zerosec.net
# udp_port_list                                                          [80]
# pyasn_as                                                              46562
# pyasn_as_bgp_size                                                     94720
# cc                                                                       US
# region                                                                  NaN
# is_oecd                                                                   1
# as_type                                                                 NaN
# as_type_confidence                                                      NaN
# tg_op                                                                   NaN
# org                                                         Colo at 55, LLC
# org_range                 (3469629696, 3469629951)-(1112014592, 11120148...
# org_rangesize                                                         79232
# org_ipsize_seen                                                         NaN
# org_domainsize_seen                                                     NaN
# org_ipsize_seen_shared                                                  NaN
# org_is_hosting                                                            0
# org_tag                                                                 NaN
# caida_type                                                   Transit/Access
# dc                                                                        2
# subs                                                                    NaN
# as_ipsize_seen                                                        19446
# as_domainsize_seen                                                   109762
# pps                                                                 2.78908
# year                                                                   2014
# Name: 398201, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5719250 entries, 0 to 5721431
# Data columns (total 35 columns):
# target_ip                 object
# date                      datetime64[ns]
# sensor_id                 object
# service                   object
# start_time                datetime64[ns]
# stop_time                 datetime64[ns]
# duration                  float64
# packets                   int64
# raw_country               object
# raw_as                    object
# raw_hostname              object
# udp_port_list             object
# pyasn_as                  float64
# pyasn_as_bgp_size         float64
# cc                        object
# region                    object
# is_oecd                   float64
# as_type                   object
# as_type_confidence        float64
# tg_op                     object
# org                       object
# org_range                 object
# org_rangesize             float64
# org_ipsize_seen           float64
# org_domainsize_seen       float64
# org_ipsize_seen_shared    float64
# org_is_hosting            float64
# org_tag                   object
# caida_type                object
# dc                        int64
# subs                      float64
# as_ipsize_seen            float64
# as_domainsize_seen        float64
# pps                       float64
# year                      int64
# dtypes: datetime64[ns](3), float64(14), int64(3), object(15)
# memory usage: 1.5+ GB

# %%
df.as_type.unique()
# Out:
# array(['isp-broadband', nan, 'isp-other', 'isp-mobile',
#        'other-intermediary', 'hosting', 'non-intermediary', 'gov', 'edu'],
#       dtype=object)

# %%
df.org_tag.unique()
# Out:
# array([nan, 'other', 'isp-mobile', 'isp-broadband', 'isp-other',
#        'hosting', 'cdn', 'edu', 'gov'], dtype=object)

# %% [markdown]
# ### Major hosting providers

# %%
# a list of major hosting providers
hosts = ["godaddy", "amazon", "google", "1&1", "squarespace", "hostgator", "ovh", "hetzner", "softlayer", "liquid web"]

# %%
majorhps = (df[df.org.str.contains("|".join(hosts), case=False, na=False)]
              [["org", "org_tag", "as_type", "as_ipsize_seen", "org_ipsize_seen"]]
              .drop_duplicates()
              .sort_values(by=["org"]))

# %%
majorhps.to_csv("major-hosting-providers.csv")

# %% [markdown]
# ### CDNs

# %%
cdn = df[df.org_tag == "cdn"][["org", "org_tag", "as_type", "as_ipsize_seen", "org_ipsize_seen"]].drop_duplicates()

# %%
# cloudflare
(df[df.org.str.contains("cloudflare", case=False, na=False)]
   [["org", "org_tag", "as_type", "as_ipsize_seen", "org_ipsize_seen", "cc"]]
   .drop_duplicates())
# Out:
#                             org org_tag as_type  as_ipsize_seen  \
# 8499                 CloudFlare     cdn     NaN        122283.0
# 8501                 CloudFlare     cdn     NaN        122283.0
# 13452                CloudFlare     cdn     NaN        122283.0
# 31561                CloudFlare     cdn     NaN        122283.0
# 31579                CloudFlare     cdn     NaN        122283.0
# 31597                CloudFlare     cdn     NaN        122283.0
# 127572               CloudFlare     cdn     NaN        122283.0
# 128575               CloudFlare     cdn     NaN        122283.0
# 128578               CloudFlare     cdn     NaN        122283.0
# 341994               CloudFlare     cdn     NaN        122283.0
# 1277733              CloudFlare     cdn     NaN             NaN
# 1277791              CloudFlare     cdn     NaN        122283.0
# 2167744  CloudFlare CDN network     cdn     NaN        122283.0
# 2168180  CloudFlare CDN network     cdn     NaN        122283.0
# 2262876              CloudFlare     cdn     NaN            96.0
#
#          org_ipsize_seen   cc
# 8499             88540.0   JP
# 8501             88540.0   HK
# 13452            88540.0   US
# 31561            88540.0   CA
# 31579            88540.0   FR
# 31597            88540.0   NO
# 127572           88540.0  NaN
# 128575           88540.0   AT
# 128578           88540.0   GB
# 341994           88540.0   CR
# 1277733          88540.0   US
# 1277791          88540.0   AU
# 2167744           1045.0  NaN
# 2168180           1045.0   GB
# 2262876          88540.0   US

# %%
(df[df.org.str.contains("akamai", case=False, na=False)]
   [["org", "org_tag", "as_type", "as_ipsize_seen", "org_ipsize_seen", "cc"]]
   .drop_duplicates())
# Out:
#                                                        org        org_tag  \
# 12347                                  Akamai Technologies            cdn
# 18829                                  Akamai Technologies            cdn
# 18837                                  Akamai Technologies            cdn
# 83971                                  Akamai Technologies            cdn
# 118972                                              Akamai            NaN
# 144896                                              Akamai            NaN
# 160561                                              Akamai            NaN
# 168011                                 Akamai Technologies            cdn
# 176762                                 Akamai Technologies            cdn
# 245556                                 Akamai Technologies            cdn
# 248112                            Akamai International, BV            cdn
# 248118                                 Akamai Technologies            cdn
# 367599                                 Akamai Technologies            cdn
# 372527                                 Akamai Technologies            cdn
# 378639                                 Akamai Technologies            cdn
# 379092            Akamai Technologies Gmbh Sucursal Espana  isp-broadband
# 379096                             Akamai International BV            NaN
# 404574                                 Akamai Technologies            cdn
# 404686                                 Akamai Technologies            cdn
# 404689                                 Akamai Technologies            cdn
# 404692                                 Akamai Technologies            cdn
# 404847                                 Akamai Technologies            cdn
# 405025                                 Akamai Technologies            cdn
# 405054                                 Akamai Technologies            cdn
# 405060                                 Akamai Technologies            cdn
# 405061                                 Akamai Technologies            cdn
# 405529                                 Akamai Technologies            cdn
# 405534                                 Akamai Technologies            cdn
# 405537                                 Akamai Technologies            cdn
# 405547                                 Akamai Technologies            cdn
# ...                                                    ...            ...
# 3652450                           Akamai International, BV            cdn
# 3708813                          Akamai Technologies Tokyo            NaN
# 3708974                           Akamai International, BV            cdn
# 3709476                           Akamai International, BV            cdn
# 3710241                                Akamai Technologies            cdn
# 3733986                                             Akamai            NaN
# 4344257                            Akamai International BV            NaN
# 4353881                     TTT Akamai Manchester Platfrom            NaN
# 4461851                                Akamai Technologies            cdn
# 4466616                                      Embarq Akamai            NaN
# 4597414                                Akamai Technologies            cdn
# 4919416                                   Akamai Amsterdam            NaN
# 4919423                                   Akamai Frankfurt            NaN
# 5052167                            Akamai International BV            NaN
# 5052169                            Akamai International BV            NaN
# 5052229                            Akamai International BV            NaN
# 5052245                           Akamai international V B  isp-broadband
# 5052350                                             Akamai            NaN
# 5080788                                             Akamai            NaN
# 5083145                                         AKAMAI-LAN  isp-broadband
# 5101689                       NDC-hosting castup/Akamai RH        hosting
# 5144863                Akamai implementation at Nianet A/S      isp-other
# 5296372                          RETN Akamai Kiev CDN node            cdn
# 5329246                                Akamai Technologies            cdn
# 5442066                                Akamai Technologies            cdn
# 5442132                                Akamai Technologies            cdn
# 5488610                          Akamai Port80 Linknetwork            NaN
# 5496656  Akamai Servers in Telecom Italia International...            NaN
# 5558263                                Akamai Technologies            cdn
# 5558338                                Akamai Technologies            cdn
#
#                as_type  as_ipsize_seen  org_ipsize_seen   cc
# 12347              NaN        118405.0        1567292.0   US
# 18829              NaN       1531580.0        1567292.0   US
# 18837    isp-broadband       1568045.0        1567292.0   US
# 83971              NaN        119372.0        1567292.0   SG
# 118972       isp-other        683571.0          12076.0   US
# 144896             NaN       1531580.0          12076.0   US
# 160561             NaN        118405.0          12076.0   US
# 168011         hosting        937404.0        1567292.0   US
# 176762             NaN        304812.0        1567292.0   US
# 245556   isp-broadband         13773.0        1567292.0   US
# 248112             NaN        683571.0         430031.0   NL
# 248118             NaN           587.0        1567292.0   US
# 367599             NaN           587.0        1567292.0  NaN
# 372527   isp-broadband        719093.0        1567292.0   DE
# 378639             NaN       1531580.0        1567292.0  NaN
# 379092             NaN       1531580.0              4.0   ES
# 379096      isp-mobile         96673.0           2829.0   GB
# 404574             NaN        937404.0        1567292.0  NaN
# 404686             NaN        719093.0        1567292.0  NaN
# 404689             NaN         96673.0        1567292.0  NaN
# 404692             NaN          7838.0        1567292.0   NL
# 404847             NaN         51300.0        1567292.0  NaN
# 405025             NaN       1531580.0        1567292.0   AT
# 405054             NaN       1531580.0        1567292.0   NL
# 405060             NaN        442872.0        1567292.0  NaN
# 405061             NaN        937404.0        1567292.0   AT
# 405529             NaN        304812.0        1567292.0   GB
# 405534             NaN          7838.0        1567292.0   GB
# 405537             NaN         51300.0        1567292.0   FR
# 405547             NaN       1531580.0        1567292.0   BE
# ...                ...             ...              ...  ...
# 3652450            NaN          7838.0         430031.0   NL
# 3708813            NaN          1289.0           1007.0   US
# 3708974            NaN         11266.0         430031.0   NL
# 3709476            NaN           587.0         430031.0   US
# 3710241            NaN           243.0        1567292.0   NL
# 3733986      isp-other          4771.0          12076.0   US
# 4344257            NaN         96673.0           2829.0   ES
# 4353881  isp-broadband         21891.0              NaN   GB
# 4461851            NaN          1305.0        1567292.0   US
# 4466616  isp-broadband        216705.0              NaN   US
# 4597414      isp-other         93235.0        1567292.0   US
# 4919416            NaN          4933.0            112.0   CH
# 4919423            NaN          4933.0            124.0   CH
# 5052167            NaN        181496.0           2829.0   NL
# 5052169            NaN        181496.0           2829.0  NaN
# 5052229            NaN        181496.0           2829.0   AT
# 5052245            NaN        181496.0            221.0  NaN
# 5052350            NaN        181496.0          12076.0   DE
# 5080788            NaN          3704.0          12076.0   NL
# 5083145  isp-broadband         31637.0              4.0   IL
# 5101689     isp-mobile          7196.0              1.0   IL
# 5144863      isp-other          8215.0              1.0   DK
# 5296372            NaN           121.0             53.0   GB
# 5329246            NaN          3704.0        1567292.0   IL
# 5442066            NaN         96673.0        1567292.0   DE
# 5442132            NaN         23352.0        1567292.0  NaN
# 5488610            NaN         11266.0              NaN   SE
# 5496656            NaN         23352.0            446.0   GR
# 5558263            NaN        937404.0        1567292.0   IT
# 5558338            NaN         38395.0        1567292.0  NaN
#
# [146 rows x 6 columns]
